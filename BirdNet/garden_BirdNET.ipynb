# %%
from birdnetlib import Recording
from birdnetlib.analyzer import Analyzer
from datetime import datetime

# Load and initialize the BirdNET-Analyzer models.
analyzer = Analyzer()
bfile = "bird-voices.mp3"
recording = Recording(
    analyzer,
    bfile,
    lat=51.41778,
    lon=5.462251,
    date=datetime(year=2022, month=5, day=10), # use date or week_48
    min_conf=0.25,
)
recording.analyze()
print(recording.detections)
# Out:
# Labels loaded.
# load model True
# Model loaded.
# Labels loaded.
# load_species_list_model
# Meta model loaded.
# read_audio_data
# read_audio_data: complete, read  34 chunks.
# analyze_recording bird-voices.mp3
# recording has lon/lat
# set_predicted_species_list_from_position
# return_predicted_species_list
# 18
# 151 species loaded.
# [{'common_name': 'Willow Warbler', 'scientific_name': 'Phylloscopus trochilus', 'start_time': 6.0, 'end_time': 9.0, 'confidence': 0.4909761846065521, 'label': 'Phylloscopus trochilus_Willow Warbler'}, {'common_name': 'Willow Warbler', 'scientific_name': 'Phylloscopus trochilus', 'start_time': 21.0, 'end_time': 24.0, 'confidence': 0.42529934644699097, 'label': 'Phylloscopus trochilus_Willow Warbler'}, {'common_name': 'European Robin', 'scientific_name': 'Erithacus rubecula', 'start_time': 24.0, 'end_time': 27.0, 'confidence': 0.6579822301864624, 'label': 'Erithacus rubecula_European Robin'}, {'common_name': 'European Robin', 'scientific_name': 'Erithacus rubecula', 'start_time': 27.0, 'end_time': 30.0, 'confidence': 0.5578925013542175, 'label': 'Erithacus rubecula_European Robin'}, {'common_name': 'European Robin', 'scientific_name': 'Erithacus rubecula', 'start_time': 42.0, 'end_time': 45.0, 'confidence': 0.6492666602134705, 'label': 'Erithacus rubecula_European Robin'}, {'common_name': 'European Robin', 'scientific_name': 'Erithacus rubecula', 'start_time': 66.0, 'end_time': 69.0, 'confidence': 0.3281049430370331, 'label': 'Erithacus rubecula_European Robin'}, {'common_name': 'European Robin', 'scientific_name': 'Erithacus rubecula', 'start_time': 69.0, 'end_time': 72.0, 'confidence': 0.5592458248138428, 'label': 'Erithacus rubecula_European Robin'}, {'common_name': 'Long-tailed Tit', 'scientific_name': 'Aegithalos caudatus', 'start_time': 87.0, 'end_time': 90.0, 'confidence': 0.8710739612579346, 'label': 'Aegithalos caudatus_Long-tailed Tit'}]

# %%
import os
import pandas as pd

def find_files(root_folder):
    """
    Finds the metadata file and audio files in the specified root folder.
    The root folder is assumed to contain subfolders with audio files and metadata file.
    The metadata file is assumed to be named '...metadata.xlsx' and the audio files are assumed to have the extension '.wav'.
    parameters:
    - root_folder: The path to the root folder containing the audio files and metadata file.
    returns:
    - metadata_filepath: The path to the metadata file.
    - audio_files: A list of relative paths to the audio files.

    """
    audio_files = []
    metadata_filepath = None
    for dirpath, dirnames, filenames in os.walk(root_folder):
        for filename in filenames:
            if filename.endswith('metadata.xlsx'):
                metadata_filepath = os.path.join(dirpath, filename)
                print(f"Found metadata file: {metadata_filepath}")

            elif filename.endswith('.wav'):
                audio_files.append(os.path.join(dirpath, filename))
            

    return metadata_filepath, audio_files

# %%
import pandas as pd
import os

def add_labels(metadata_file_path, results,column_name):
    """
    Adds the BirdNET labels to the metadata file.
    parameters:
    - metadata_file_path: The relative path to the metadata file.
    - results: A list of tuples containing the filepath and BirdNET label.

    """
    # Create a DataFrame from results
    labels_df = pd.DataFrame(results, columns=['filepath', column_name])
    
    # Extract basenames for comparison
    labels_df['filename'] = labels_df['filepath'].apply(os.path.basename)
    
    # Load the existing metadata DataFrame
    df = pd.read_excel(metadata_file_path)
    
    # Ensure filenames are basenames for comparison
    df['filename'] = df['filename'].apply(os.path.basename)
    
    # Check if the 'BirdNET_label' column exists; if not, create it with NaN values
    if column_name not in df.columns:
        df[column_name] = pd.NA
    
    # Merge the existing df with the labels_df
    df = df.merge(labels_df[['filename', column_name]], on='filename', how='left', suffixes=('', '_new'))
    
    # Update the 'BirdNET_label' column with new values where available
    df[column_name] = df[column_name+'_new'].combine_first(df[column_name])
    
    # Drop the temporary 'BirdNET_label_new' column
    df.drop('BirdNET_label_new', axis=1, inplace=True)
 
    # Construct the new filename
    original_filename = os.path.basename(metadata_file_path)
    new_filename = original_filename.replace('metadata', column_name+'_metadata')
    new_filepath = os.path.join(os.path.dirname(metadata_file_path), new_filename)
    # Save the updated DataFrame to a new Excel file
    df.to_excel(new_filepath, index=False)

# %%
def analyze_files_birdnet(list_files_paths):  
    """Analyzer for BirdNET
    parameters:
    - list_files_paths: List of file paths to analyze
    returns:
    - results: A list of tuples containing the filepath and BirdNET label.
    """  
    results = []
    for file in list_files_paths:
        try:
            recording = Recording(
                analyzer,
                file,
                lat=51.41778,
                lon=5.462251,
                date=datetime(year=2022, month=5, day=10), # use date or week_48
                min_conf=0.25,
            )
            recording.analyze()
            if len(recording.detections) > 0:
                results.append((file, recording.detections[0]['label']))
        except Exception as e:
            print(f"Error processing file {file}: {e}")
    return results

# %%
# new pipeline for birdnet processing
def pipeline_birdnet(folder_path):
    """
    Pipeline for processing audio files with BirdNET.
    parameters:
    - folder_path: The path to the root folder containing the audio files and metadata file.
    """
    metadata_file_path, audio_files_paths = find_files(folder_path)
    results = analyze_files_birdnet(audio_files_paths)
    add_labels(metadata_file_path, results, 'BirdNET')

# %%
gatden_folder = '../garden_19102023'
pipeline_birdnet(gatden_folder)
# Out:
# Found metadata file: ../garden_19102023/garden_19102023_metadata.xlsx
# Found metadata file: ../garden_19102023/garden_19102023_birdnet_metadata.xlsx
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_55_54.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_18_42.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_41_08.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_39_04.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_59_41.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_57_50.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_54_03.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_57_52.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_31_29.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_40_15.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_12_35.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_45_52.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_56_12.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_08_50.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_15_29.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_42_05.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_57_47.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_26_24.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_00_08.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_54_12.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_07_11.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_54_06.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_08_54.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_20_55.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_12_19.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_32_42.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_15_48.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_44_05.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_44_10.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_27_10.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_12_40.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_25_15.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_51_44.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_45_18.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_27_13.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_20_26.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_53_54.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_04_23.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_27_17.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_34_42.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_22_26.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_22_32.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_43_40.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_32_23.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_40_11.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_40_05.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_40_07.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_21_49.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_04_34.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_11_00.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_27_29.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_19_58.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_14_24.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_09_49.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_21_51.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_22_14.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_35_33.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_04_13.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_30_02.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_27_32.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_27_26.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_32_13.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_09_46.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_59_38.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_27_22.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_29_33.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_30_07.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_46_51.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_57_00.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_32_02.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_21_56.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_41_11.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_10_48.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_01_19.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_58_46.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_27_08.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_40_50.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_04_28.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_35_20.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_29_56.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_11_46.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_24_02.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_56_25.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_40_34.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_34_10.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_58_22.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_20_58.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_15_08.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_07_20.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_16_54_33.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_00_05.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_25_50.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_38_29.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_36_10.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_05_35.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_26_00.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_25_53.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_29_52.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_29_46.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_17_26_03.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_58_57.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_55_03.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_49_13.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_40_37.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_37_42.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_31_37.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_55_00.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_57_39.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_29_54.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_33_30.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_40_34.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_04_13.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_44_44.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_50_25.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_31_34.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_59_05.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_33_34.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_33_20.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_50_08.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_58_44.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_58_52.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_29_46.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_33_23.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_40_32.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_49_16.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_01_31.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_46_47.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_01_25.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_56_56.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_58_08.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_31_55.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_32_04.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_32_10.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_50_50.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_50_44.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_30_01.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_37_34.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_40_40.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_44_18.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_51_11.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_58_21.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_05_33.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_31_42.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_32_13.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_32_07.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_44_32.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_44_26.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_30_16.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_37_22.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_01_44.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_32_16.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_50_56.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_40_46.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_40_52.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_41_06.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_51_03.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_51_29.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_32_01.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_37_25.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_37_19.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_30_05.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_37_30.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_44_35.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_57_49.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_44_09.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_31_51.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_02_26.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_31_48.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_32_19.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_44_38.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_50_59.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_30_08.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_00_23.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_40_49.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_49_45.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_37_28.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_32_26.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_37_17.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_58_03.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_02_24.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_30_27.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_01_58.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_58_06.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_02_21.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_49_40.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_44_14.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_31_58.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_31_17.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_01_28.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_59_22.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_01_01.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_32_51.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_58_48.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_31_39.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_32_54.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_29_59.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_36_25.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_49_22.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_14_40_07.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_15_01_10.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_45_42.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_20_37.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_09_15.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_03_49.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_54_06.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_16_40.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_22_33.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_58_04.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_42_48.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_10_37.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_09_03.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_22_30.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_49_44.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_09_12.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_18_43.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_02_27.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_28_40.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_28_56.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_49_47.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_54_03.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_14_54.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_02_24.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_23_01.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_28_24.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_12_52.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_12_46.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_34_34.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_51_55.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_23_59.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_47_27.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_53_53.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_38_33.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_38_27.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_13_28.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_19_49.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_17_59.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_53_42.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_12_55.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_28_37.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_38_30.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_23_53.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_18_06.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_53_58.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_04_02.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_44_55.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_14_13.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_21_43.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_56_55.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_12_58.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_01_24.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_06_05.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_25_52.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_23_33.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_44_42.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_15_33.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_58_47.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_18_10.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_26_02.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_12_49.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_18_14.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_15_37.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_04_05.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_25_56.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_28_28.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_52_21.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_17_19.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_49_39.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_59_00.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_23_43.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_14_49.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_23_30.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_09_08.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_44_36.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_09_21.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_13_51.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_10_58_27.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_18_58.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_11_12_39.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# ...
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_46_22.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_30_17.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_26_11.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_09_25.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_09_31.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_42_18.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_42_30.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_46_33.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_09_35.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_10_01.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_38_17.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_46_19.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_45_48.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_37_09.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_29_21.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_09_50.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_49_13.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_41_14.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_32_38.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_09_45.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_27_19.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_39_25.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_19_09.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_39_44.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_23_09.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_01_26.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_28_38.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_59_04.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_57_15.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_31_46.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_07_47.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_09_42.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_33_21.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_14_12.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_50_21.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_40_47.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_11_20.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_23_51.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_59_07.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_49_03.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_28_06.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_20_29.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_27_05.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_00_41.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_10_45.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_31_29.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_41_23.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_13_03.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_41_37.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_25_02.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_36_56.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_50_39.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_28_35.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_18_22.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_37_06.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_30_27.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_10_42.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_36_52.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_41_33.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_00_47.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_49_09.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_23_05.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_24_30.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_19_12.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_09_48.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_41_30.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_00_51.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_29_10.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_27_15.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_26_26.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_49_44.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_49_50.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_17_07.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_10_26.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_10_32.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_12_23.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_42_10.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_10_18.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_26_19.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_24_21.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_38_43.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_42_15.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_09_28.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_41_50.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_07_38.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_04_55.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_24_24.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_42_02.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_20_08.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_26_22.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_55_44.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_20_41_25.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# read_audio_data
# read_audio_data: complete, read  1 chunks.
# analyze_recording er_file_2023_10_19_21_24_27.wav
# recording has lon/lat
# set_predicted_species_list_from_position
